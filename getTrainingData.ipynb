# %%
import cv2

cam = cv2.VideoCapture(0)

cv2.namedWindow("test")

img_counter = 0

while True:
    ret, frame = cam.read()           
    if not ret:
        print("failed to grab frame")
        break
    cv2.imshow("test", frame)

    k = cv2.waitKey(1)
    if k%256 == 27:
        # ESC pressed
        print("Escape hit, closing...")
        break    
    elif k%256 == 32:
        # SPACE pressed             
        img_name = "seven{}.png".format(img_counter)
        cv2.imwrite(img_name, frame)
        print("{} written!".format(img_name))
        img_counter += 1

cam.release()

cv2.destroyAllWindows()
# Out:
# seven0.png written!
# seven1.png written!
# seven2.png written!
# seven3.png written!
# seven4.png written!
# seven5.png written!
# seven6.png written!
# seven7.png written!
# seven8.png written!
# seven9.png written!
# seven10.png written!
# seven11.png written!
# seven12.png written!
# seven13.png written!
# seven14.png written!
# seven15.png written!
# seven16.png written!
# seven17.png written!
# seven18.png written!
# seven19.png written!
# seven20.png written!
# seven21.png written!
# seven22.png written!
# seven23.png written!
# seven24.png written!
# seven25.png written!
# seven26.png written!
# seven27.png written!
# seven28.png written!
# seven29.png written!
# seven30.png written!
# seven31.png written!
# seven32.png written!
# seven33.png written!
# seven34.png written!
# seven35.png written!
# seven36.png written!
# seven37.png written!
# seven38.png written!
# seven39.png written!
# seven40.png written!
# seven41.png written!
# seven42.png written!
# seven43.png written!
# seven44.png written!
# seven45.png written!
# seven46.png written!
# seven47.png written!
# seven48.png written!
# seven49.png written!
# seven50.png written!
# seven51.png written!
# seven52.png written!
# seven53.png written!
# seven54.png written!
# seven55.png written!
# seven56.png written!
# seven57.png written!
# seven58.png written!
# seven59.png written!
# seven60.png written!
# seven61.png written!
# seven62.png written!
# seven63.png written!
# seven64.png written!
# seven65.png written!
# seven66.png written!
# seven67.png written!
# seven68.png written!
# seven69.png written!
# seven70.png written!
# seven71.png written!
# seven72.png written!
# seven73.png written!
# seven74.png written!
# seven75.png written!
# seven76.png written!
# seven77.png written!
# seven78.png written!
# seven79.png written!
